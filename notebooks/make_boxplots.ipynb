# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import lasio

from make_boxplots import *

# %%
df = lasio.read('../data/no_31!1-3_s_lfp_tiny.las').df()
LFP_CALI(df)
LFP_DRHO(df)
LFP_DT_LOG(df)
LFP_DTS_LOG(df)
LFP_DTST_LOG(df)
LFP_GR(df)
# LFP_K(df)
LFP_NPHI(df)
LFP_PEF(df)
LFP_RHOB_LOG(df)
LFP_RM(df)
LFP_RS(df)
LFP_RT_LOG(df)
# LFP_TH(df)
# LFP_U(df)
